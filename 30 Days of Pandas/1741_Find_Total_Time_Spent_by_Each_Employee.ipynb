# %% [markdown]
# # Code Of The Problem

# %%
import pandas as pd

def total_time(employees: pd.DataFrame) -> pd.DataFrame:
    employees['total_time'] = employees['out_time'] - employees['in_time']
    res = employees.groupby(['emp_id','event_day'])['total_time'].sum().reset_index()
    res.rename(columns={'event_day':'day'}, inplace=True)
    return res

# %% [markdown]
# # Why add "reset_index()" ?!

# %%
import pandas as pd
df= pd.DataFrame({'id':[1,2,3,2,1,1],
                  'date':['2020/12/1','2020/12/2','2020/12/3','2020/12/2','2020/12/1','2020/12/4'],
                  'in':[5,4,9,2,3,7],
                  'out':[20,40,90,12,33,22]})

# %%
df
# Out:
#    id       date  in  out
# 0   1  2020/12/1   5   20
# 1   2  2020/12/2   4   40
# 2   3  2020/12/3   9   90
# 3   2  2020/12/2   2   12
# 4   1  2020/12/1   3   33
# 5   1  2020/12/4   7   22

# %%
df['total_time'] = df['out'] - df['in']
res1 = df.groupby(['id','date'])['total_time'].sum()

# %%
res1
# Out:
# id  date
# 1   2020/12/1    45
#     2020/12/4    15
# 2   2020/12/2    46
# 3   2020/12/3    81
# Name: total_time, dtype: int64

# %%
print(type(res1))
# Out:
# <class 'pandas.core.series.Series'>

# %%
res2 = df.groupby(['id','date'])['total_time'].sum().reset_index()

# %%
res2
# Out:
#    id       date  total_time
# 0   1  2020/12/1          45
# 1   1  2020/12/4          15
# 2   2  2020/12/2          46
# 3   3  2020/12/3          81

# %%
print(type(res2))
# Out:
# <class 'pandas.core.frame.DataFrame'>
