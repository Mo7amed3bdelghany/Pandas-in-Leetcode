# %% [markdown]
# # melt():
# https://colab.research.google.com/drive/14poJ9qPbiCrsUJQCY2Jhz-XaqHv7j6sL?usp=sharing

# %%
import pandas as pd

def rearrange_products_table(products: pd.DataFrame) -> pd.DataFrame:
    return pd.melt(products, id_vars=['product_id'],var_name='store', value_name='price').dropna()

# %% [markdown]
# ## OR

# %%
import pandas as pd

def rearrange_products_table(products: pd.DataFrame) -> pd.DataFrame:
    return pd.melt(products, id_vars=['product_id'],value_vars = ['store1','store2','store3'],var_name='store', value_name='price').dropna()
